# %%
import os
import sys
from pathlib import Path

import pandas as pd

# Add project root to Python path
project_root = Path.cwd().parent
sys.path.append(str(project_root))

# Import processors
from processors.data_processor import (
    DataPreprocessor,
)
# Out:
# /tmp/ipykernel_272335/3298189028.py:5: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd
# [nltk_data] Downloading package punkt to /home/bitrao/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /home/bitrao/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /home/bitrao/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
comments_df = pd.read_csv('../data/raw/youtube_comments_luther.csv')

# %%
comments_df.head()
# Out:
#                                                   id     video_id  \
# 0                         UgxHLK6T175yluj-QM14AaABAg  HfWLgELllZs
# 1  UgxHLK6T175yluj-QM14AaABAg.AB9MwSW6WhFAB9fOdTRrng  HfWLgELllZs
# 2  UgxHLK6T175yluj-QM14AaABAg.AB9MwSW6WhFAB9oQscsPGg  HfWLgELllZs
# 3  UgxHLK6T175yluj-QM14AaABAg.AB9MwSW6WhFAB9ssCqghcr  HfWLgELllZs
# 4  UgxHLK6T175yluj-QM14AaABAg.AB9MwSW6WhFABAOYMlTF_w  HfWLgELllZs
#
#                     parent_id                author  \
# 0                         NaN            @thebsmoke
# 1  UgxHLK6T175yluj-QM14AaABAg  @montassarkhdhir9854
# 2  UgxHLK6T175yluj-QM14AaABAg           @tsudot9800
# 3  UgxHLK6T175yluj-QM14AaABAg       @LoganDavis-p4j
# 4  UgxHLK6T175yluj-QM14AaABAg     @marlynnjones1355
#
#                                                 text          published_at  \
# 0  The flow 🔥<br>The beat 🔥<br>The melody 🔥<br>Th...  2024-11-22T19:26:02Z
# 1                                       The lyrics 🔥  2024-11-22T22:16:03Z
# ...

# %%
processor = DataPreprocessor()

# %%
processed_df = processor.preprocess_data(comments_df, text_column='text')

# %%
processed_df.head()
# Out:
#                                                   id     video_id  \
# 0                         UgxHLK6T175yluj-QM14AaABAg  HfWLgELllZs
# 1  UgxHLK6T175yluj-QM14AaABAg.AB9MwSW6WhFAB9fOdTRrng  HfWLgELllZs
# 2  UgxHLK6T175yluj-QM14AaABAg.AB9MwSW6WhFAB9oQscsPGg  HfWLgELllZs
# 3  UgxHLK6T175yluj-QM14AaABAg.AB9MwSW6WhFAB9ssCqghcr  HfWLgELllZs
# 4  UgxHLK6T175yluj-QM14AaABAg.AB9MwSW6WhFABAOYMlTF_w  HfWLgELllZs
#
#                     parent_id                author  \
# 0                         NaN            @thebsmoke
# 1  UgxHLK6T175yluj-QM14AaABAg  @montassarkhdhir9854
# 2  UgxHLK6T175yluj-QM14AaABAg           @tsudot9800
# 3  UgxHLK6T175yluj-QM14AaABAg       @LoganDavis-p4j
# 4  UgxHLK6T175yluj-QM14AaABAg     @marlynnjones1355
#
#                                                 text          published_at  \
# 0  The flow 🔥<br>The beat 🔥<br>The melody 🔥<br>Th...  2024-11-22T19:26:02Z
# 1                                       The lyrics 🔥  2024-11-22T22:16:03Z
# ...

# %%
processed_df['text'] = processed_df['cleaned_text']
processed_df.drop(columns=['cleaned_text'], inplace=True)

# %%
# Count NaN values in the processed dataframe
print("Number of NaN values in processed dataframe:")
print(processed_df.isna().sum())
# Out:
# Number of NaN values in processed dataframe:
# id                 0
# video_id           0
# parent_id       8097
# author             4
# text               0
# published_at       0
# likes              0
# is_reply           0
# video_title        0
# category           0
# dtype: int64

# %%
output_path = Path('../data/processed/youtube_comments_luther_processed.csv')
processor.save_processed_data(processed_df, output_path)
# Out:
# PosixPath('../data/processed/youtube_comments_luther_processed.csv')
